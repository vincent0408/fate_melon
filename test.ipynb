# %%
import ddddocr
import cv2
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
pipe = subprocess.Popen("adb -s emulator-5554 shell screencap -p",
                        stdin=subprocess.PIPE,
                        stdout=subprocess.PIPE, shell=True)
image_bytes = pipe.stdout.read().replace(b'\r\n', b'\n')
image = cv2.imdecode(np.frombuffer(image_bytes, np.uint8), cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY), cmap='gray')

# %%
(cv2.imread('pause_btn_l.png') == cv2.threshold(image[790:860, 770:840],127,255,cv2.THRESH_BINARY)[1]).all()
# Out:
# True

# %%
cv2.threshold(image[790:860, 770:840],127,255,cv2.THRESH_BINARY)[1].shape
# Out:
# (70, 70, 3)

# %%
plt.imsave('pause_btn_p.png', cv2.threshold(image[1415:1485, 420:490],127,255,cv2.THRESH_BINARY)[1])

# %%
plt.imshow(cv2.threshold(image[1410:1480, 420:490],127,255,cv2.THRESH_BINARY)[1], cmap='gray')

# %%
plt.imshow(cv2.imread("pause_btn_p.png"))

# %%
plt.imshow(cv2.imread("pause_btn_l.png"))

# %%
pbl = cv2.imread("pause_btn_l.png")
pbp = cv2.imread("pause_btn_p.png")

# %%
for i in range(70):
    if((pbl == np.roll(pbp, i, axis=0)).all()):
        print(i)
        break
# Out:
# 4

# %%
(pbl == cv2.threshold(image[1411:1481, 420:490],127,255,cv2.THRESH_BINARY)[1]).all()
# Out:
# True
